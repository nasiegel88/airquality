# %%
# Read in packages included in conda
#library(tidyverse)

# %% [markdown]
# This analysis was done using the [PWFSLSmoke](https://cran.r-project.org/web/packages/PWFSLSmoke/vignettes/PWFSLSmoke.html) R package.

# %%
source("00-R/main.R")

# %%
camp_fire <-
  monitor_loadAnnual(2018) %>%
  monitor_subset(stateCodes = 'CA') %>%
  monitor_subset(tlim = c(20181108, 20181123))

# %%
camp_fire
# Out:
# $meta
#                                                                   monitorID
# 060231005_01                                                   060231005_01
# 060072002_01                                                   060072002_01
# MMCA81010_01                                                   MMCA81010_01
# 060376012_01                                                   060376012_01
# 061110009_01                                                   061110009_01
# 060959999_01                                                   060959999_01
# 060631007_01                                                   060631007_01
# 060010011_01                                                   060010011_01
# 060871005_01                                                   060871005_01
# 060611004_01                                                   060611004_01
# 060010012_01                                                   060010012_01
# ...
